# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import joblib
import re
import os

# %%
# Load the data
df = pd.read_csv(r'C:\Users\honey\Documents\placment work\Electronical-AI-Device-Recogniser\khanya\data managment\datasets\acs-f2-dataset.csv')

# Data Preprocessing
# Drop the 'time' column as it's not relevant for prediction
df = df.drop('time', axis=1)

# Convert categorical labels to numeric
le = LabelEncoder()
df['equipment'] = le.fit_transform(df['equipment'])

# Split features and labels
X = df.drop('equipment', axis=1)
y = df['equipment']

# %%
#Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Handle class imbalance using SMOTE
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X_scaled, y)

# One-hot encode the target labels
num_classes = len(np.unique(y))
y_resampled_onehot = to_categorical(y_resampled, num_classes=num_classes)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled_onehot, test_size=0.2, random_state=42)

# %%
# Define the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")
print(f"Test loss: {test_loss:.4f}")

# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# Epoch 1/500
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.3626 - loss: 1.8448 - val_accuracy: 0.5494 - val_loss: 1.2669
# Epoch 2/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.5315 - loss: 1.3026 - val_accuracy: 0.6178 - val_loss: 1.0584
# Epoch 3/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.5868 - loss: 1.1457 - val_accuracy: 0.6600 - val_loss: 0.9643
# Epoch 4/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.6204 - loss: 1.0529 - val_accuracy: 0.6819 - val_loss: 0.8993
# Epoch 5/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6394 - loss: 0.9948 - val_accuracy: 0.6942 - val_loss: 0.8458
# Epoch 6/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.6543 - loss: 0.9543 - val_accuracy: 0.7085 - val_loss: 0.8061
# Epoch 7/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6656 - loss: 0.9207 - val_accuracy: 0.7122 - val_loss: 0.7933
# Epoch 8/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.6752 - loss: 0.9031 - val_accuracy: 0.7286 - val_loss: 0.7698
# Epoch 9/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6845 - loss: 0.8772 - val_accuracy: 0.7329 - val_loss: 0.7546
# Epoch 10/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6883 - loss: 0.8642 - val_accuracy: 0.7355 - val_loss: 0.7418
# Epoch 11/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6967 - loss: 0.8381 - val_accuracy: 0.7420 - val_loss: 0.7241
# Epoch 12/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7026 - loss: 0.8258 - val_accuracy: 0.7423 - val_loss: 0.7155
# Epoch 13/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7054 - loss: 0.8176 - val_accuracy: 0.7393 - val_loss: 0.7135
# Epoch 14/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7068 - loss: 0.8090 - val_accuracy: 0.7466 - val_loss: 0.7034
# Epoch 15/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7121 - loss: 0.8000 - val_accuracy: 0.7460 - val_loss: 0.6978
# Epoch 16/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7142 - loss: 0.7949 - val_accuracy: 0.7526 - val_loss: 0.6889
# Epoch 17/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7172 - loss: 0.7847 - val_accuracy: 0.7442 - val_loss: 0.6995
# Epoch 18/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7188 - loss: 0.7788 - val_accuracy: 0.7531 - val_loss: 0.6879
# Epoch 19/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7193 - loss: 0.7729 - val_accuracy: 0.7537 - val_loss: 0.6768
# Epoch 20/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7196 - loss: 0.7717 - val_accuracy: 0.7600 - val_loss: 0.6644
# Epoch 21/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7239 - loss: 0.7630 - val_accuracy: 0.7575 - val_loss: 0.6668
# Epoch 22/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7271 - loss: 0.7579 - val_accuracy: 0.7576 - val_loss: 0.6613
# Epoch 23/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7246 - loss: 0.7602 - val_accuracy: 0.7575 - val_loss: 0.6671
# Epoch 24/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7292 - loss: 0.7537 - val_accuracy: 0.7645 - val_loss: 0.6518
# Epoch 25/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7267 - loss: 0.7563 - val_accuracy: 0.7602 - val_loss: 0.6563
# Epoch 26/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7322 - loss: 0.7430 - val_accuracy: 0.7600 - val_loss: 0.6543
# Epoch 27/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7326 - loss: 0.7440 - val_accuracy: 0.7625 - val_loss: 0.6524
# Epoch 28/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7321 - loss: 0.7385 - val_accuracy: 0.7650 - val_loss: 0.6521
# Epoch 29/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7339 - loss: 0.7371 - val_accuracy: 0.7632 - val_loss: 0.6511
# Epoch 30/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7377 - loss: 0.7316 - val_accuracy: 0.7720 - val_loss: 0.6419
# Epoch 31/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7371 - loss: 0.7317 - val_accuracy: 0.7668 - val_loss: 0.6453
# Epoch 32/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7398 - loss: 0.7230 - val_accuracy: 0.7682 - val_loss: 0.6470
# Epoch 33/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7357 - loss: 0.7321 - val_accuracy: 0.7736 - val_loss: 0.6358
# Epoch 34/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7372 - loss: 0.7284 - val_accuracy: 0.7701 - val_loss: 0.6362
# Epoch 35/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7427 - loss: 0.7163 - val_accuracy: 0.7687 - val_loss: 0.6353
# Epoch 36/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7404 - loss: 0.7216 - val_accuracy: 0.7721 - val_loss: 0.6314
# Epoch 37/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7386 - loss: 0.7190 - val_accuracy: 0.7698 - val_loss: 0.6325
# Epoch 38/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7399 - loss: 0.7189 - val_accuracy: 0.7692 - val_loss: 0.6318
# Epoch 39/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7440 - loss: 0.7128 - val_accuracy: 0.7714 - val_loss: 0.6375
# Epoch 40/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7430 - loss: 0.7170 - val_accuracy: 0.7733 - val_loss: 0.6288
# Epoch 41/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7417 - loss: 0.7111 - val_accuracy: 0.7726 - val_loss: 0.6280
# Epoch 42/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7430 - loss: 0.7118 - val_accuracy: 0.7728 - val_loss: 0.6269
# Epoch 43/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7431 - loss: 0.7100 - val_accuracy: 0.7763 - val_loss: 0.6259
# Epoch 44/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7439 - loss: 0.7098 - val_accuracy: 0.7761 - val_loss: 0.6223
# Epoch 45/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7452 - loss: 0.7076 - val_accuracy: 0.7784 - val_loss: 0.6176
# Epoch 46/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7459 - loss: 0.7069 - val_accuracy: 0.7714 - val_loss: 0.6215
# Epoch 47/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7438 - loss: 0.7092 - val_accuracy: 0.7656 - val_loss: 0.6378
# Epoch 48/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7463 - loss: 0.7059 - val_accuracy: 0.7740 - val_loss: 0.6260
# Epoch 49/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7448 - loss: 0.7098 - val_accuracy: 0.7798 - val_loss: 0.6188
# Epoch 50/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7464 - loss: 0.7024 - val_accuracy: 0.7774 - val_loss: 0.6182
# Epoch 51/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7470 - loss: 0.7017 - val_accuracy: 0.7768 - val_loss: 0.6135
# Epoch 52/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7471 - loss: 0.7023 - val_accuracy: 0.7764 - val_loss: 0.6220
# Epoch 53/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7496 - loss: 0.6958 - val_accuracy: 0.7803 - val_loss: 0.6088
# Epoch 54/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7477 - loss: 0.7007 - val_accuracy: 0.7764 - val_loss: 0.6190
# Epoch 55/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7464 - loss: 0.7006 - val_accuracy: 0.7811 - val_loss: 0.6151
# Epoch 56/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7503 - loss: 0.6923 - val_accuracy: 0.7757 - val_loss: 0.6172
# Epoch 57/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7498 - loss: 0.6944 - val_accuracy: 0.7761 - val_loss: 0.6116
# Epoch 58/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7507 - loss: 0.6903 - val_accuracy: 0.7772 - val_loss: 0.6190
# Epoch 59/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7509 - loss: 0.6883 - val_accuracy: 0.7797 - val_loss: 0.6123
# Epoch 60/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7503 - loss: 0.6921 - val_accuracy: 0.7842 - val_loss: 0.6082
# Epoch 61/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7497 - loss: 0.6972 - val_accuracy: 0.7824 - val_loss: 0.6064
# Epoch 62/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7525 - loss: 0.6880 - val_accuracy: 0.7760 - val_loss: 0.6100
# Epoch 63/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7526 - loss: 0.6877 - val_accuracy: 0.7790 - val_loss: 0.6124
# Epoch 64/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7526 - loss: 0.6829 - val_accuracy: 0.7834 - val_loss: 0.6015
# Epoch 65/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7568 - loss: 0.6776 - val_accuracy: 0.7764 - val_loss: 0.6095
# Epoch 66/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7500 - loss: 0.6901 - val_accuracy: 0.7801 - val_loss: 0.6035
# Epoch 67/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7532 - loss: 0.6863 - val_accuracy: 0.7801 - val_loss: 0.6072
# Epoch 68/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7533 - loss: 0.6840 - val_accuracy: 0.7784 - val_loss: 0.6077
# Epoch 69/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7549 - loss: 0.6801 - val_accuracy: 0.7815 - val_loss: 0.6008
# Epoch 70/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7541 - loss: 0.6825 - val_accuracy: 0.7805 - val_loss: 0.6006
# Epoch 71/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7529 - loss: 0.6798 - val_accuracy: 0.7811 - val_loss: 0.6074
# Epoch 72/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7540 - loss: 0.6853 - val_accuracy: 0.7790 - val_loss: 0.6084
# Epoch 73/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7526 - loss: 0.6884 - val_accuracy: 0.7813 - val_loss: 0.6031
# Epoch 74/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7540 - loss: 0.6864 - val_accuracy: 0.7808 - val_loss: 0.6023
# Epoch 75/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7565 - loss: 0.6799 - val_accuracy: 0.7820 - val_loss: 0.6052
# Epoch 76/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7555 - loss: 0.6817 - val_accuracy: 0.7849 - val_loss: 0.6003
# Epoch 77/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7550 - loss: 0.6781 - val_accuracy: 0.7812 - val_loss: 0.6069
# Epoch 78/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7555 - loss: 0.6798 - val_accuracy: 0.7798 - val_loss: 0.6032
# Epoch 79/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7579 - loss: 0.6743 - val_accuracy: 0.7801 - val_loss: 0.6042
# Epoch 80/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7556 - loss: 0.6794 - val_accuracy: 0.7816 - val_loss: 0.6026
# Epoch 81/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7569 - loss: 0.6758 - val_accuracy: 0.7798 - val_loss: 0.6072
# Epoch 82/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7542 - loss: 0.6798 - val_accuracy: 0.7840 - val_loss: 0.5983
# Epoch 83/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7511 - loss: 0.6882 - val_accuracy: 0.7842 - val_loss: 0.5980
# Epoch 84/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7578 - loss: 0.6761 - val_accuracy: 0.7842 - val_loss: 0.6022
# Epoch 85/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7557 - loss: 0.6785 - val_accuracy: 0.7826 - val_loss: 0.6018
# Epoch 86/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7589 - loss: 0.6722 - val_accuracy: 0.7762 - val_loss: 0.6060
# Epoch 87/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7582 - loss: 0.6744 - val_accuracy: 0.7837 - val_loss: 0.5970
# Epoch 88/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7571 - loss: 0.6741 - val_accuracy: 0.7830 - val_loss: 0.6019
# Epoch 89/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7546 - loss: 0.6823 - val_accuracy: 0.7794 - val_loss: 0.6076
# Epoch 90/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7575 - loss: 0.6761 - val_accuracy: 0.7816 - val_loss: 0.5972
# Epoch 91/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7557 - loss: 0.6737 - val_accuracy: 0.7831 - val_loss: 0.5991
# Epoch 92/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7576 - loss: 0.6762 - val_accuracy: 0.7796 - val_loss: 0.6031
# Epoch 93/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7568 - loss: 0.6746 - val_accuracy: 0.7844 - val_loss: 0.5926
# Epoch 94/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7589 - loss: 0.6718 - val_accuracy: 0.7856 - val_loss: 0.5900
# Epoch 95/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7579 - loss: 0.6777 - val_accuracy: 0.7837 - val_loss: 0.5943
# Epoch 96/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7556 - loss: 0.6786 - val_accuracy: 0.7880 - val_loss: 0.5874
# Epoch 97/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7582 - loss: 0.6752 - val_accuracy: 0.7823 - val_loss: 0.6007
# Epoch 98/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7599 - loss: 0.6689 - val_accuracy: 0.7873 - val_loss: 0.5882
# Epoch 99/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7599 - loss: 0.6689 - val_accuracy: 0.7841 - val_loss: 0.5953
# Epoch 100/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7584 - loss: 0.6723 - val_accuracy: 0.7803 - val_loss: 0.6097
# Epoch 101/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7594 - loss: 0.6644 - val_accuracy: 0.7822 - val_loss: 0.6032
# Epoch 102/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7596 - loss: 0.6697 - val_accuracy: 0.7807 - val_loss: 0.6049
# Epoch 103/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7583 - loss: 0.6739 - val_accuracy: 0.7849 - val_loss: 0.5952
# Epoch 104/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7579 - loss: 0.6709 - val_accuracy: 0.7854 - val_loss: 0.5918
# Epoch 105/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7624 - loss: 0.6619 - val_accuracy: 0.7842 - val_loss: 0.5909
# Epoch 106/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7593 - loss: 0.6676 - val_accuracy: 0.7850 - val_loss: 0.5993
# Epoch 107/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7616 - loss: 0.6633 - val_accuracy: 0.7846 - val_loss: 0.5919
# Epoch 108/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7589 - loss: 0.6701 - val_accuracy: 0.7805 - val_loss: 0.5960
# Epoch 109/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7614 - loss: 0.6676 - val_accuracy: 0.7864 - val_loss: 0.5928
# Epoch 110/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7603 - loss: 0.6649 - val_accuracy: 0.7865 - val_loss: 0.5924
# Epoch 111/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7614 - loss: 0.6661 - val_accuracy: 0.7887 - val_loss: 0.5910
# Epoch 112/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7622 - loss: 0.6634 - val_accuracy: 0.7824 - val_loss: 0.5914
# Epoch 113/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7623 - loss: 0.6628 - val_accuracy: 0.7817 - val_loss: 0.5971
# Epoch 114/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7623 - loss: 0.6583 - val_accuracy: 0.7859 - val_loss: 0.5941
# Epoch 115/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7602 - loss: 0.6663 - val_accuracy: 0.7828 - val_loss: 0.5937
# Epoch 116/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7617 - loss: 0.6609 - val_accuracy: 0.7813 - val_loss: 0.5965
# Epoch 117/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7597 - loss: 0.6653 - val_accuracy: 0.7873 - val_loss: 0.5860
# Epoch 118/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7619 - loss: 0.6612 - val_accuracy: 0.7865 - val_loss: 0.5897
# Epoch 119/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7631 - loss: 0.6568 - val_accuracy: 0.7853 - val_loss: 0.5918
# Epoch 120/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7610 - loss: 0.6653 - val_accuracy: 0.7828 - val_loss: 0.6003
# Epoch 121/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7597 - loss: 0.6651 - val_accuracy: 0.7818 - val_loss: 0.5968
# Epoch 122/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7626 - loss: 0.6594 - val_accuracy: 0.7861 - val_loss: 0.5927
# Epoch 123/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7602 - loss: 0.6635 - val_accuracy: 0.7838 - val_loss: 0.5962
# Epoch 124/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7624 - loss: 0.6627 - val_accuracy: 0.7813 - val_loss: 0.5982
# Epoch 125/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7584 - loss: 0.6679 - val_accuracy: 0.7827 - val_loss: 0.5931
# Epoch 126/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7613 - loss: 0.6615 - val_accuracy: 0.7889 - val_loss: 0.5850
# Epoch 127/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7613 - loss: 0.6623 - val_accuracy: 0.7858 - val_loss: 0.5985
# Epoch 128/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7613 - loss: 0.6604 - val_accuracy: 0.7863 - val_loss: 0.5833
# Epoch 129/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7615 - loss: 0.6617 - val_accuracy: 0.7849 - val_loss: 0.5877
# Epoch 130/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7617 - loss: 0.6616 - val_accuracy: 0.7888 - val_loss: 0.5857
# Epoch 131/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7619 - loss: 0.6606 - val_accuracy: 0.7829 - val_loss: 0.5957
# Epoch 132/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7607 - loss: 0.6630 - val_accuracy: 0.7898 - val_loss: 0.5843
# Epoch 133/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7607 - loss: 0.6613 - val_accuracy: 0.7912 - val_loss: 0.5809
# Epoch 134/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7587 - loss: 0.6667 - val_accuracy: 0.7870 - val_loss: 0.5895
# Epoch 135/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7616 - loss: 0.6620 - val_accuracy: 0.7877 - val_loss: 0.5868
# Epoch 136/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7606 - loss: 0.6612 - val_accuracy: 0.7835 - val_loss: 0.5966
# Epoch 137/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7630 - loss: 0.6575 - val_accuracy: 0.7873 - val_loss: 0.5888
# Epoch 138/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7633 - loss: 0.6545 - val_accuracy: 0.7878 - val_loss: 0.5850
# Epoch 139/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7632 - loss: 0.6591 - val_accuracy: 0.7793 - val_loss: 0.6032
# Epoch 140/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7642 - loss: 0.6549 - val_accuracy: 0.7842 - val_loss: 0.5967
# Epoch 141/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7652 - loss: 0.6537 - val_accuracy: 0.7826 - val_loss: 0.5941
# Epoch 142/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7649 - loss: 0.6568 - val_accuracy: 0.7894 - val_loss: 0.5856
# Epoch 143/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7655 - loss: 0.6527 - val_accuracy: 0.7897 - val_loss: 0.5852
# Epoch 144/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7638 - loss: 0.6549 - val_accuracy: 0.7862 - val_loss: 0.5909
# Epoch 145/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7625 - loss: 0.6609 - val_accuracy: 0.7904 - val_loss: 0.5856
# Epoch 146/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7650 - loss: 0.6503 - val_accuracy: 0.7872 - val_loss: 0.5876
# Epoch 147/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7647 - loss: 0.6571 - val_accuracy: 0.7908 - val_loss: 0.5870
# Epoch 148/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7632 - loss: 0.6577 - val_accuracy: 0.7887 - val_loss: 0.5836
# Epoch 149/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7619 - loss: 0.6574 - val_accuracy: 0.7836 - val_loss: 0.5979
# Epoch 150/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7630 - loss: 0.6566 - val_accuracy: 0.7886 - val_loss: 0.5827
# Epoch 151/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7636 - loss: 0.6584 - val_accuracy: 0.7881 - val_loss: 0.5850
# Epoch 152/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7665 - loss: 0.6528 - val_accuracy: 0.7868 - val_loss: 0.5933
# Epoch 153/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7662 - loss: 0.6526 - val_accuracy: 0.7869 - val_loss: 0.5883
# Epoch 154/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7633 - loss: 0.6569 - val_accuracy: 0.7860 - val_loss: 0.5873
# Epoch 155/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7652 - loss: 0.6493 - val_accuracy: 0.7892 - val_loss: 0.5866
# Epoch 156/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7625 - loss: 0.6598 - val_accuracy: 0.7900 - val_loss: 0.5845
# Epoch 157/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7635 - loss: 0.6550 - val_accuracy: 0.7887 - val_loss: 0.5836
# Epoch 158/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7647 - loss: 0.6529 - val_accuracy: 0.7831 - val_loss: 0.5931
# Epoch 159/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7660 - loss: 0.6530 - val_accuracy: 0.7887 - val_loss: 0.5794
# Epoch 160/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7661 - loss: 0.6550 - val_accuracy: 0.7891 - val_loss: 0.5897
# Epoch 161/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7645 - loss: 0.6519 - val_accuracy: 0.7880 - val_loss: 0.5845
# Epoch 162/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7632 - loss: 0.6600 - val_accuracy: 0.7884 - val_loss: 0.5822
# Epoch 163/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7660 - loss: 0.6533 - val_accuracy: 0.7890 - val_loss: 0.5804
# Epoch 164/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7670 - loss: 0.6462 - val_accuracy: 0.7904 - val_loss: 0.5778
# Epoch 165/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7643 - loss: 0.6556 - val_accuracy: 0.7928 - val_loss: 0.5749
# Epoch 166/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7672 - loss: 0.6489 - val_accuracy: 0.7883 - val_loss: 0.5858
# Epoch 167/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7627 - loss: 0.6584 - val_accuracy: 0.7891 - val_loss: 0.5828
# Epoch 168/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7657 - loss: 0.6538 - val_accuracy: 0.7881 - val_loss: 0.5816
# Epoch 169/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7662 - loss: 0.6475 - val_accuracy: 0.7899 - val_loss: 0.5829
# Epoch 170/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7661 - loss: 0.6488 - val_accuracy: 0.7887 - val_loss: 0.5837
# Epoch 171/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7667 - loss: 0.6495 - val_accuracy: 0.7895 - val_loss: 0.5830
# Epoch 172/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7695 - loss: 0.6442 - val_accuracy: 0.7890 - val_loss: 0.5793
# Epoch 173/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7643 - loss: 0.6536 - val_accuracy: 0.7888 - val_loss: 0.5762
# Epoch 174/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7675 - loss: 0.6500 - val_accuracy: 0.7898 - val_loss: 0.5850
# Epoch 175/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7644 - loss: 0.6526 - val_accuracy: 0.7909 - val_loss: 0.5792
# Epoch 176/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7671 - loss: 0.6469 - val_accuracy: 0.7921 - val_loss: 0.5782
# Epoch 177/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7645 - loss: 0.6514 - val_accuracy: 0.7926 - val_loss: 0.5806
# Epoch 178/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7693 - loss: 0.6449 - val_accuracy: 0.7881 - val_loss: 0.5874
# Epoch 179/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7654 - loss: 0.6472 - val_accuracy: 0.7907 - val_loss: 0.5810
# Epoch 180/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7704 - loss: 0.6372 - val_accuracy: 0.7870 - val_loss: 0.5888
# Epoch 181/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7644 - loss: 0.6518 - val_accuracy: 0.7888 - val_loss: 0.5822
# Epoch 182/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7641 - loss: 0.6537 - val_accuracy: 0.7893 - val_loss: 0.5852
# Epoch 183/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7662 - loss: 0.6501 - val_accuracy: 0.7892 - val_loss: 0.5846
# Epoch 184/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7684 - loss: 0.6462 - val_accuracy: 0.7911 - val_loss: 0.5827
# Epoch 185/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7680 - loss: 0.6427 - val_accuracy: 0.7911 - val_loss: 0.5745
# Epoch 186/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7678 - loss: 0.6444 - val_accuracy: 0.7909 - val_loss: 0.5822
# Epoch 187/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7650 - loss: 0.6490 - val_accuracy: 0.7917 - val_loss: 0.5813
# Epoch 188/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7654 - loss: 0.6521 - val_accuracy: 0.7895 - val_loss: 0.5762
# Epoch 189/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7683 - loss: 0.6440 - val_accuracy: 0.7872 - val_loss: 0.5908
# Epoch 190/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7660 - loss: 0.6517 - val_accuracy: 0.7879 - val_loss: 0.5827
# Epoch 191/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7658 - loss: 0.6521 - val_accuracy: 0.7893 - val_loss: 0.5818
# Epoch 192/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7683 - loss: 0.6488 - val_accuracy: 0.7903 - val_loss: 0.5784
# Epoch 193/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7667 - loss: 0.6475 - val_accuracy: 0.7902 - val_loss: 0.5783
# Epoch 194/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7684 - loss: 0.6435 - val_accuracy: 0.7883 - val_loss: 0.5794
# Epoch 195/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7662 - loss: 0.6492 - val_accuracy: 0.7928 - val_loss: 0.5739
# Epoch 196/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7672 - loss: 0.6469 - val_accuracy: 0.7841 - val_loss: 0.5970
# Epoch 197/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7677 - loss: 0.6463 - val_accuracy: 0.7934 - val_loss: 0.5773
# Epoch 198/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7679 - loss: 0.6439 - val_accuracy: 0.7907 - val_loss: 0.5790
# Epoch 199/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7698 - loss: 0.6424 - val_accuracy: 0.7915 - val_loss: 0.5781
# Epoch 200/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7670 - loss: 0.6485 - val_accuracy: 0.7917 - val_loss: 0.5769
# Epoch 201/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7662 - loss: 0.6472 - val_accuracy: 0.7881 - val_loss: 0.5875
# Epoch 202/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7700 - loss: 0.6410 - val_accuracy: 0.7900 - val_loss: 0.5774
# Epoch 203/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7687 - loss: 0.6416 - val_accuracy: 0.7880 - val_loss: 0.5836
# Epoch 204/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7662 - loss: 0.6481 - val_accuracy: 0.7938 - val_loss: 0.5766
# Epoch 205/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7710 - loss: 0.6464 - val_accuracy: 0.7902 - val_loss: 0.5799
# Epoch 206/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7681 - loss: 0.6469 - val_accuracy: 0.7929 - val_loss: 0.5736
# Epoch 207/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7683 - loss: 0.6462 - val_accuracy: 0.7897 - val_loss: 0.5792
# Epoch 208/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7684 - loss: 0.6446 - val_accuracy: 0.7912 - val_loss: 0.5853
# Epoch 209/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7703 - loss: 0.6427 - val_accuracy: 0.7897 - val_loss: 0.5852
# Epoch 210/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7683 - loss: 0.6402 - val_accuracy: 0.7907 - val_loss: 0.5795
# Epoch 211/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7708 - loss: 0.6373 - val_accuracy: 0.7924 - val_loss: 0.5788
# Epoch 212/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7686 - loss: 0.6427 - val_accuracy: 0.7907 - val_loss: 0.5794
# Epoch 213/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7676 - loss: 0.6455 - val_accuracy: 0.7869 - val_loss: 0.5911
# Epoch 214/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7665 - loss: 0.6491 - val_accuracy: 0.7924 - val_loss: 0.5758
# Epoch 215/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7702 - loss: 0.6355 - val_accuracy: 0.7917 - val_loss: 0.5799
# Epoch 216/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7685 - loss: 0.6457 - val_accuracy: 0.7877 - val_loss: 0.5862
# Epoch 217/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7709 - loss: 0.6400 - val_accuracy: 0.7913 - val_loss: 0.5781
# Epoch 218/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7705 - loss: 0.6395 - val_accuracy: 0.7905 - val_loss: 0.5733
# Epoch 219/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7681 - loss: 0.6382 - val_accuracy: 0.7934 - val_loss: 0.5734
# Epoch 220/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7690 - loss: 0.6422 - val_accuracy: 0.7911 - val_loss: 0.5785
# Epoch 221/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7682 - loss: 0.6447 - val_accuracy: 0.7846 - val_loss: 0.5908
# Epoch 222/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7708 - loss: 0.6361 - val_accuracy: 0.7955 - val_loss: 0.5736
# Epoch 223/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7702 - loss: 0.6396 - val_accuracy: 0.7890 - val_loss: 0.5781
# Epoch 224/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7691 - loss: 0.6431 - val_accuracy: 0.7937 - val_loss: 0.5713
# Epoch 225/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7692 - loss: 0.6400 - val_accuracy: 0.7914 - val_loss: 0.5779
# Epoch 226/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7674 - loss: 0.6466 - val_accuracy: 0.7885 - val_loss: 0.5811
# Epoch 227/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7689 - loss: 0.6402 - val_accuracy: 0.7913 - val_loss: 0.5776
# Epoch 228/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7705 - loss: 0.6405 - val_accuracy: 0.7883 - val_loss: 0.5845
# Epoch 229/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7691 - loss: 0.6413 - val_accuracy: 0.7934 - val_loss: 0.5702
# Epoch 230/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7697 - loss: 0.6398 - val_accuracy: 0.7877 - val_loss: 0.5811
# Epoch 231/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7707 - loss: 0.6440 - val_accuracy: 0.7900 - val_loss: 0.5889
# Epoch 232/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7698 - loss: 0.6418 - val_accuracy: 0.7929 - val_loss: 0.5765
# Epoch 233/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7687 - loss: 0.6406 - val_accuracy: 0.7914 - val_loss: 0.5755
# Epoch 234/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7715 - loss: 0.6368 - val_accuracy: 0.7861 - val_loss: 0.5849
# Epoch 235/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7704 - loss: 0.6423 - val_accuracy: 0.7895 - val_loss: 0.5785
# Epoch 236/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7691 - loss: 0.6451 - val_accuracy: 0.7875 - val_loss: 0.5856
# Epoch 237/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7712 - loss: 0.6363 - val_accuracy: 0.7903 - val_loss: 0.5775
# Epoch 238/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7691 - loss: 0.6455 - val_accuracy: 0.7920 - val_loss: 0.5785
# Epoch 239/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7700 - loss: 0.6421 - val_accuracy: 0.7933 - val_loss: 0.5738
# Epoch 240/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7724 - loss: 0.6355 - val_accuracy: 0.7967 - val_loss: 0.5691
# Epoch 241/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7705 - loss: 0.6386 - val_accuracy: 0.7939 - val_loss: 0.5745
# Epoch 242/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7695 - loss: 0.6372 - val_accuracy: 0.7923 - val_loss: 0.5757
# Epoch 243/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7724 - loss: 0.6355 - val_accuracy: 0.7932 - val_loss: 0.5742
# Epoch 244/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7702 - loss: 0.6443 - val_accuracy: 0.7916 - val_loss: 0.5720
# Epoch 245/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7720 - loss: 0.6356 - val_accuracy: 0.7929 - val_loss: 0.5732
# Epoch 246/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7699 - loss: 0.6374 - val_accuracy: 0.7940 - val_loss: 0.5771
# Epoch 247/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7719 - loss: 0.6331 - val_accuracy: 0.7913 - val_loss: 0.5788
# Epoch 248/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7737 - loss: 0.6360 - val_accuracy: 0.7944 - val_loss: 0.5704
# Epoch 249/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7691 - loss: 0.6425 - val_accuracy: 0.7921 - val_loss: 0.5773
# Epoch 250/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7706 - loss: 0.6394 - val_accuracy: 0.7930 - val_loss: 0.5765
# Epoch 251/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7725 - loss: 0.6366 - val_accuracy: 0.7933 - val_loss: 0.5758
# Epoch 252/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7706 - loss: 0.6397 - val_accuracy: 0.7926 - val_loss: 0.5751
# Epoch 253/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7702 - loss: 0.6410 - val_accuracy: 0.7877 - val_loss: 0.5798
# Epoch 254/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7717 - loss: 0.6389 - val_accuracy: 0.7919 - val_loss: 0.5734
# Epoch 255/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7722 - loss: 0.6352 - val_accuracy: 0.7897 - val_loss: 0.5766
# Epoch 256/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7691 - loss: 0.6405 - val_accuracy: 0.7913 - val_loss: 0.5753
# Epoch 257/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7712 - loss: 0.6379 - val_accuracy: 0.7928 - val_loss: 0.5776
# Epoch 258/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7699 - loss: 0.6393 - val_accuracy: 0.7915 - val_loss: 0.5809
# Epoch 259/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7701 - loss: 0.6371 - val_accuracy: 0.7909 - val_loss: 0.5750
# Epoch 260/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7703 - loss: 0.6380 - val_accuracy: 0.7924 - val_loss: 0.5754
# Epoch 261/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7721 - loss: 0.6358 - val_accuracy: 0.7947 - val_loss: 0.5710
# Epoch 262/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7720 - loss: 0.6377 - val_accuracy: 0.7916 - val_loss: 0.5758
# Epoch 263/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7699 - loss: 0.6399 - val_accuracy: 0.7947 - val_loss: 0.5720
# Epoch 264/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7708 - loss: 0.6382 - val_accuracy: 0.7922 - val_loss: 0.5794
# Epoch 265/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7676 - loss: 0.6361 - val_accuracy: 0.7929 - val_loss: 0.5692
# Epoch 266/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7713 - loss: 0.6370 - val_accuracy: 0.7930 - val_loss: 0.5770
# Epoch 267/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7714 - loss: 0.6378 - val_accuracy: 0.7940 - val_loss: 0.5705
# Epoch 268/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7718 - loss: 0.6352 - val_accuracy: 0.7903 - val_loss: 0.5816
# Epoch 269/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7729 - loss: 0.6294 - val_accuracy: 0.7963 - val_loss: 0.5722
# Epoch 270/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7689 - loss: 0.6452 - val_accuracy: 0.7908 - val_loss: 0.5809
# Epoch 271/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7715 - loss: 0.6381 - val_accuracy: 0.7882 - val_loss: 0.5828
# Epoch 272/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7713 - loss: 0.6336 - val_accuracy: 0.7952 - val_loss: 0.5686
# Epoch 273/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7716 - loss: 0.6307 - val_accuracy: 0.7937 - val_loss: 0.5725
# Epoch 274/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7719 - loss: 0.6340 - val_accuracy: 0.7923 - val_loss: 0.5730
# Epoch 275/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7716 - loss: 0.6368 - val_accuracy: 0.7937 - val_loss: 0.5736
# Epoch 276/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7711 - loss: 0.6356 - val_accuracy: 0.7935 - val_loss: 0.5729
# Epoch 277/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7722 - loss: 0.6317 - val_accuracy: 0.7890 - val_loss: 0.5831
# Epoch 278/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7700 - loss: 0.6355 - val_accuracy: 0.7938 - val_loss: 0.5764
# Epoch 279/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7729 - loss: 0.6370 - val_accuracy: 0.7946 - val_loss: 0.5754
# Epoch 280/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7725 - loss: 0.6291 - val_accuracy: 0.7936 - val_loss: 0.5716
# Epoch 281/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7732 - loss: 0.6321 - val_accuracy: 0.7929 - val_loss: 0.5740
# Epoch 282/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7706 - loss: 0.6380 - val_accuracy: 0.7954 - val_loss: 0.5750
# Epoch 283/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7721 - loss: 0.6329 - val_accuracy: 0.7950 - val_loss: 0.5798
# Epoch 284/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7697 - loss: 0.6401 - val_accuracy: 0.7905 - val_loss: 0.5790
# Epoch 285/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7686 - loss: 0.6392 - val_accuracy: 0.7945 - val_loss: 0.5713
# Epoch 286/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7712 - loss: 0.6420 - val_accuracy: 0.7902 - val_loss: 0.5825
# Epoch 287/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7705 - loss: 0.6391 - val_accuracy: 0.7944 - val_loss: 0.5726
# Epoch 288/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7713 - loss: 0.6362 - val_accuracy: 0.7913 - val_loss: 0.5763
# Epoch 289/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7698 - loss: 0.6352 - val_accuracy: 0.7928 - val_loss: 0.5705
# Epoch 290/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7728 - loss: 0.6302 - val_accuracy: 0.7938 - val_loss: 0.5681
# Epoch 291/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7719 - loss: 0.6341 - val_accuracy: 0.7939 - val_loss: 0.5696
# Epoch 292/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7732 - loss: 0.6325 - val_accuracy: 0.7954 - val_loss: 0.5704
# Epoch 293/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7726 - loss: 0.6351 - val_accuracy: 0.7960 - val_loss: 0.5661
# Epoch 294/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7734 - loss: 0.6354 - val_accuracy: 0.7945 - val_loss: 0.5703
# Epoch 295/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7701 - loss: 0.6393 - val_accuracy: 0.7958 - val_loss: 0.5690
# Epoch 296/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7720 - loss: 0.6333 - val_accuracy: 0.7942 - val_loss: 0.5728
# Epoch 297/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7723 - loss: 0.6350 - val_accuracy: 0.7940 - val_loss: 0.5729
# Epoch 298/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7742 - loss: 0.6252 - val_accuracy: 0.7898 - val_loss: 0.5794
# Epoch 299/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7686 - loss: 0.6439 - val_accuracy: 0.7935 - val_loss: 0.5759
# Epoch 300/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7721 - loss: 0.6350 - val_accuracy: 0.7890 - val_loss: 0.5790
# Epoch 301/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7703 - loss: 0.6364 - val_accuracy: 0.7959 - val_loss: 0.5750
# Epoch 302/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7702 - loss: 0.6404 - val_accuracy: 0.7960 - val_loss: 0.5707
# Epoch 303/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7722 - loss: 0.6347 - val_accuracy: 0.7889 - val_loss: 0.5821
# Epoch 304/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7712 - loss: 0.6407 - val_accuracy: 0.7928 - val_loss: 0.5723
# Epoch 305/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7710 - loss: 0.6293 - val_accuracy: 0.7956 - val_loss: 0.5694
# Epoch 306/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7724 - loss: 0.6374 - val_accuracy: 0.7932 - val_loss: 0.5738
# Epoch 307/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7739 - loss: 0.6294 - val_accuracy: 0.7921 - val_loss: 0.5735
# Epoch 308/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7723 - loss: 0.6322 - val_accuracy: 0.7945 - val_loss: 0.5684
# Epoch 309/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7708 - loss: 0.6382 - val_accuracy: 0.7923 - val_loss: 0.5751
# Epoch 310/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7702 - loss: 0.6411 - val_accuracy: 0.7928 - val_loss: 0.5705
# Epoch 311/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7712 - loss: 0.6360 - val_accuracy: 0.7892 - val_loss: 0.5794
# Epoch 312/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7716 - loss: 0.6342 - val_accuracy: 0.7923 - val_loss: 0.5770
# Epoch 313/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7764 - loss: 0.6238 - val_accuracy: 0.7924 - val_loss: 0.5738
# Epoch 314/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7725 - loss: 0.6354 - val_accuracy: 0.7933 - val_loss: 0.5756
# Epoch 315/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7728 - loss: 0.6341 - val_accuracy: 0.7930 - val_loss: 0.5734
# Epoch 316/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7720 - loss: 0.6382 - val_accuracy: 0.7969 - val_loss: 0.5648
# Epoch 317/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7746 - loss: 0.6252 - val_accuracy: 0.7951 - val_loss: 0.5702
# Epoch 318/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7730 - loss: 0.6303 - val_accuracy: 0.7933 - val_loss: 0.5724
# Epoch 319/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7710 - loss: 0.6374 - val_accuracy: 0.7968 - val_loss: 0.5703
# Epoch 320/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7717 - loss: 0.6309 - val_accuracy: 0.7919 - val_loss: 0.5769
# Epoch 321/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7739 - loss: 0.6336 - val_accuracy: 0.7929 - val_loss: 0.5698
# Epoch 322/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7726 - loss: 0.6320 - val_accuracy: 0.7948 - val_loss: 0.5779
# Epoch 323/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7736 - loss: 0.6331 - val_accuracy: 0.7960 - val_loss: 0.5669
# Epoch 324/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7713 - loss: 0.6395 - val_accuracy: 0.7966 - val_loss: 0.5668
# Epoch 325/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7751 - loss: 0.6230 - val_accuracy: 0.7903 - val_loss: 0.5813
# Epoch 326/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7728 - loss: 0.6340 - val_accuracy: 0.7939 - val_loss: 0.5649
# Epoch 327/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7716 - loss: 0.6382 - val_accuracy: 0.7907 - val_loss: 0.5742
# Epoch 328/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7739 - loss: 0.6317 - val_accuracy: 0.7949 - val_loss: 0.5703
# Epoch 329/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7726 - loss: 0.6336 - val_accuracy: 0.7988 - val_loss: 0.5672
# Epoch 330/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7720 - loss: 0.6341 - val_accuracy: 0.7956 - val_loss: 0.5652
# Epoch 331/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7769 - loss: 0.6293 - val_accuracy: 0.7961 - val_loss: 0.5697
# Epoch 332/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7721 - loss: 0.6336 - val_accuracy: 0.7970 - val_loss: 0.5688
# Epoch 333/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7734 - loss: 0.6311 - val_accuracy: 0.7964 - val_loss: 0.5680
# Epoch 334/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7743 - loss: 0.6365 - val_accuracy: 0.7944 - val_loss: 0.5743
# Epoch 335/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7743 - loss: 0.6297 - val_accuracy: 0.7931 - val_loss: 0.5717
# Epoch 336/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7693 - loss: 0.6361 - val_accuracy: 0.7939 - val_loss: 0.5739
# Epoch 337/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7737 - loss: 0.6287 - val_accuracy: 0.7951 - val_loss: 0.5745
# Epoch 338/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7725 - loss: 0.6308 - val_accuracy: 0.7958 - val_loss: 0.5724
# Epoch 339/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7783 - loss: 0.6182 - val_accuracy: 0.7927 - val_loss: 0.5715
# Epoch 340/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7739 - loss: 0.6323 - val_accuracy: 0.7949 - val_loss: 0.5763
# Epoch 341/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7748 - loss: 0.6285 - val_accuracy: 0.7923 - val_loss: 0.5761
# Epoch 342/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7734 - loss: 0.6317 - val_accuracy: 0.7941 - val_loss: 0.5733
# Epoch 343/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7711 - loss: 0.6341 - val_accuracy: 0.7945 - val_loss: 0.5707
# Epoch 344/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7739 - loss: 0.6348 - val_accuracy: 0.7926 - val_loss: 0.5757
# Epoch 345/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7724 - loss: 0.6288 - val_accuracy: 0.7916 - val_loss: 0.5797
# Epoch 346/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7752 - loss: 0.6268 - val_accuracy: 0.7931 - val_loss: 0.5749
# Epoch 347/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7734 - loss: 0.6311 - val_accuracy: 0.7940 - val_loss: 0.5693
# Epoch 348/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7743 - loss: 0.6328 - val_accuracy: 0.7912 - val_loss: 0.5731
# Epoch 349/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7706 - loss: 0.6386 - val_accuracy: 0.7907 - val_loss: 0.5768
# Epoch 350/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7742 - loss: 0.6271 - val_accuracy: 0.7913 - val_loss: 0.5765
# Epoch 351/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7722 - loss: 0.6364 - val_accuracy: 0.7940 - val_loss: 0.5680
# Epoch 352/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7745 - loss: 0.6290 - val_accuracy: 0.7908 - val_loss: 0.5736
# Epoch 353/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7743 - loss: 0.6332 - val_accuracy: 0.7941 - val_loss: 0.5733
# Epoch 354/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7748 - loss: 0.6250 - val_accuracy: 0.7918 - val_loss: 0.5740
# Epoch 355/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7719 - loss: 0.6350 - val_accuracy: 0.7943 - val_loss: 0.5699
# Epoch 356/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7727 - loss: 0.6370 - val_accuracy: 0.7967 - val_loss: 0.5683
# Epoch 357/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7734 - loss: 0.6328 - val_accuracy: 0.7950 - val_loss: 0.5703
# Epoch 358/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7734 - loss: 0.6295 - val_accuracy: 0.7968 - val_loss: 0.5692
# Epoch 359/500
# ...
# Epoch 383/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7750 - loss: 0.6280 - val_accuracy: 0.7949 - val_loss: 0.5762
# Epoch 384/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7745 - loss: 0.6299 - val_accuracy: 0.7905 - val_loss: 0.5772
# Epoch 385/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.7746 - loss: 0.6334 - val_accuracy: 0.7936 - val_loss: 0.5729
# Epoch 386/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7725 - loss: 0.6304 - val_accuracy: 0.7957 - val_loss: 0.5681
# Epoch 387/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7767 - loss: 0.6198 - val_accuracy: 0.7953 - val_loss: 0.5664
# Epoch 388/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7745 - loss: 0.6296 - val_accuracy: 0.7979 - val_loss: 0.5658
# Epoch 389/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7743 - loss: 0.6304 - val_accuracy: 0.7971 - val_loss: 0.5692
# Epoch 390/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7728 - loss: 0.6282 - val_accuracy: 0.7975 - val_loss: 0.5681
# Epoch 391/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7757 - loss: 0.6278 - val_accuracy: 0.7952 - val_loss: 0.5706
# Epoch 392/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7745 - loss: 0.6322 - val_accuracy: 0.7985 - val_loss: 0.5664
# Epoch 393/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7744 - loss: 0.6249 - val_accuracy: 0.7928 - val_loss: 0.5719
# Epoch 394/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7736 - loss: 0.6294 - val_accuracy: 0.7995 - val_loss: 0.5658
# Epoch 395/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7767 - loss: 0.6243 - val_accuracy: 0.7945 - val_loss: 0.5778
# Epoch 396/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7753 - loss: 0.6301 - val_accuracy: 0.7973 - val_loss: 0.5730
# Epoch 397/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7738 - loss: 0.6275 - val_accuracy: 0.7875 - val_loss: 0.5863
# Epoch 398/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7738 - loss: 0.6320 - val_accuracy: 0.7946 - val_loss: 0.5721
# Epoch 399/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7744 - loss: 0.6293 - val_accuracy: 0.7955 - val_loss: 0.5736
# Epoch 400/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7761 - loss: 0.6239 - val_accuracy: 0.7977 - val_loss: 0.5695
# Epoch 401/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7754 - loss: 0.6288 - val_accuracy: 0.7981 - val_loss: 0.5709
# Epoch 402/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7756 - loss: 0.6243 - val_accuracy: 0.7958 - val_loss: 0.5675
# Epoch 403/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7737 - loss: 0.6288 - val_accuracy: 0.7952 - val_loss: 0.5693
# Epoch 404/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7757 - loss: 0.6250 - val_accuracy: 0.7958 - val_loss: 0.5704
# Epoch 405/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7762 - loss: 0.6326 - val_accuracy: 0.7943 - val_loss: 0.5701
# Epoch 406/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7769 - loss: 0.6212 - val_accuracy: 0.7968 - val_loss: 0.5707
# Epoch 407/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7725 - loss: 0.6351 - val_accuracy: 0.7919 - val_loss: 0.5763
# Epoch 408/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7731 - loss: 0.6327 - val_accuracy: 0.7954 - val_loss: 0.5745
# Epoch 409/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7746 - loss: 0.6338 - val_accuracy: 0.7938 - val_loss: 0.5739
# Epoch 410/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7734 - loss: 0.6348 - val_accuracy: 0.7979 - val_loss: 0.5674
# Epoch 411/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7714 - loss: 0.6387 - val_accuracy: 0.7947 - val_loss: 0.5708
# Epoch 412/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7726 - loss: 0.6341 - val_accuracy: 0.7946 - val_loss: 0.5681
# Epoch 413/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7766 - loss: 0.6251 - val_accuracy: 0.7936 - val_loss: 0.5776
# Epoch 414/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7757 - loss: 0.6267 - val_accuracy: 0.7897 - val_loss: 0.5819
# Epoch 415/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7725 - loss: 0.6321 - val_accuracy: 0.7925 - val_loss: 0.5738
# Epoch 416/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7732 - loss: 0.6328 - val_accuracy: 0.7970 - val_loss: 0.5730
# Epoch 417/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7760 - loss: 0.6269 - val_accuracy: 0.7956 - val_loss: 0.5746
# Epoch 418/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7758 - loss: 0.6269 - val_accuracy: 0.7987 - val_loss: 0.5643
# Epoch 419/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7716 - loss: 0.6349 - val_accuracy: 0.7979 - val_loss: 0.5689
# Epoch 420/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7758 - loss: 0.6267 - val_accuracy: 0.7969 - val_loss: 0.5679
# Epoch 421/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7723 - loss: 0.6337 - val_accuracy: 0.7954 - val_loss: 0.5727
# Epoch 422/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7721 - loss: 0.6370 - val_accuracy: 0.7943 - val_loss: 0.5729
# Epoch 423/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7748 - loss: 0.6255 - val_accuracy: 0.7973 - val_loss: 0.5643
# Epoch 424/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7765 - loss: 0.6229 - val_accuracy: 0.7932 - val_loss: 0.5752
# Epoch 425/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7746 - loss: 0.6286 - val_accuracy: 0.7969 - val_loss: 0.5624
# Epoch 426/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7753 - loss: 0.6297 - val_accuracy: 0.7944 - val_loss: 0.5757
# Epoch 427/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7778 - loss: 0.6226 - val_accuracy: 0.7958 - val_loss: 0.5719
# Epoch 428/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7709 - loss: 0.6358 - val_accuracy: 0.7958 - val_loss: 0.5654
# Epoch 429/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7757 - loss: 0.6236 - val_accuracy: 0.7948 - val_loss: 0.5710
# Epoch 430/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7745 - loss: 0.6271 - val_accuracy: 0.7958 - val_loss: 0.5685
# Epoch 431/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7768 - loss: 0.6214 - val_accuracy: 0.7960 - val_loss: 0.5737
# Epoch 432/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7745 - loss: 0.6279 - val_accuracy: 0.7978 - val_loss: 0.5688
# Epoch 433/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7747 - loss: 0.6256 - val_accuracy: 0.7963 - val_loss: 0.5645
# Epoch 434/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7753 - loss: 0.6252 - val_accuracy: 0.7954 - val_loss: 0.5773
# Epoch 435/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7748 - loss: 0.6294 - val_accuracy: 0.7958 - val_loss: 0.5677
# Epoch 436/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7741 - loss: 0.6361 - val_accuracy: 0.7947 - val_loss: 0.5740
# Epoch 437/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7742 - loss: 0.6254 - val_accuracy: 0.7945 - val_loss: 0.5768
# Epoch 438/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7791 - loss: 0.6169 - val_accuracy: 0.7962 - val_loss: 0.5662
# Epoch 439/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7794 - loss: 0.6231 - val_accuracy: 0.7953 - val_loss: 0.5715
# Epoch 440/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7720 - loss: 0.6369 - val_accuracy: 0.7958 - val_loss: 0.5704
# Epoch 441/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7757 - loss: 0.6266 - val_accuracy: 0.7932 - val_loss: 0.5715
# Epoch 442/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7767 - loss: 0.6217 - val_accuracy: 0.7978 - val_loss: 0.5677
# Epoch 443/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7796 - loss: 0.6184 - val_accuracy: 0.7960 - val_loss: 0.5699
# Epoch 444/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - accuracy: 0.7743 - loss: 0.6331 - val_accuracy: 0.7948 - val_loss: 0.5717
# Epoch 445/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7773 - loss: 0.6265 - val_accuracy: 0.7962 - val_loss: 0.5684
# Epoch 446/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7760 - loss: 0.6244 - val_accuracy: 0.7975 - val_loss: 0.5711
# Epoch 447/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7740 - loss: 0.6273 - val_accuracy: 0.7924 - val_loss: 0.5768
# Epoch 448/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7764 - loss: 0.6237 - val_accuracy: 0.7961 - val_loss: 0.5646
# Epoch 449/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7772 - loss: 0.6256 - val_accuracy: 0.7965 - val_loss: 0.5694
# Epoch 450/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7744 - loss: 0.6292 - val_accuracy: 0.7955 - val_loss: 0.5719
# Epoch 451/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7759 - loss: 0.6253 - val_accuracy: 0.7935 - val_loss: 0.5748
# Epoch 452/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7730 - loss: 0.6320 - val_accuracy: 0.7961 - val_loss: 0.5684
# Epoch 453/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7754 - loss: 0.6290 - val_accuracy: 0.7967 - val_loss: 0.5653
# Epoch 454/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7767 - loss: 0.6231 - val_accuracy: 0.7948 - val_loss: 0.5694
# Epoch 455/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7749 - loss: 0.6282 - val_accuracy: 0.7958 - val_loss: 0.5702
# Epoch 456/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7737 - loss: 0.6302 - val_accuracy: 0.7955 - val_loss: 0.5739
# Epoch 457/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7773 - loss: 0.6235 - val_accuracy: 0.7923 - val_loss: 0.5759
# Epoch 458/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7769 - loss: 0.6233 - val_accuracy: 0.7970 - val_loss: 0.5721
# Epoch 459/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7743 - loss: 0.6282 - val_accuracy: 0.7965 - val_loss: 0.5726
# Epoch 460/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7760 - loss: 0.6307 - val_accuracy: 0.7982 - val_loss: 0.5701
# Epoch 461/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7776 - loss: 0.6212 - val_accuracy: 0.7942 - val_loss: 0.5728
# Epoch 462/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7734 - loss: 0.6352 - val_accuracy: 0.7985 - val_loss: 0.5644
# Epoch 463/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7752 - loss: 0.6259 - val_accuracy: 0.7955 - val_loss: 0.5791
# Epoch 464/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7773 - loss: 0.6276 - val_accuracy: 0.7878 - val_loss: 0.5851
# Epoch 465/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7740 - loss: 0.6279 - val_accuracy: 0.7991 - val_loss: 0.5645
# Epoch 466/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7758 - loss: 0.6222 - val_accuracy: 0.7952 - val_loss: 0.5775
# Epoch 467/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7769 - loss: 0.6254 - val_accuracy: 0.7952 - val_loss: 0.5752
# Epoch 468/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7752 - loss: 0.6223 - val_accuracy: 0.7975 - val_loss: 0.5676
# Epoch 469/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7752 - loss: 0.6279 - val_accuracy: 0.7935 - val_loss: 0.5734
# Epoch 470/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7770 - loss: 0.6218 - val_accuracy: 0.7962 - val_loss: 0.5694
# Epoch 471/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7754 - loss: 0.6252 - val_accuracy: 0.7958 - val_loss: 0.5697
# Epoch 472/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7767 - loss: 0.6206 - val_accuracy: 0.7964 - val_loss: 0.5673
# Epoch 473/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7740 - loss: 0.6342 - val_accuracy: 0.7945 - val_loss: 0.5694
# Epoch 474/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7735 - loss: 0.6319 - val_accuracy: 0.7957 - val_loss: 0.5691
# Epoch 475/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7744 - loss: 0.6255 - val_accuracy: 0.7966 - val_loss: 0.5687
# Epoch 476/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7775 - loss: 0.6183 - val_accuracy: 0.7967 - val_loss: 0.5679
# Epoch 477/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7753 - loss: 0.6289 - val_accuracy: 0.7946 - val_loss: 0.5717
# Epoch 478/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7747 - loss: 0.6274 - val_accuracy: 0.7948 - val_loss: 0.5715
# Epoch 479/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7784 - loss: 0.6157 - val_accuracy: 0.7962 - val_loss: 0.5668
# Epoch 480/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7762 - loss: 0.6282 - val_accuracy: 0.7955 - val_loss: 0.5719
# Epoch 481/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7771 - loss: 0.6255 - val_accuracy: 0.7960 - val_loss: 0.5726
# Epoch 482/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7762 - loss: 0.6292 - val_accuracy: 0.7984 - val_loss: 0.5685
# Epoch 483/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7775 - loss: 0.6251 - val_accuracy: 0.7972 - val_loss: 0.5662
# Epoch 484/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7765 - loss: 0.6208 - val_accuracy: 0.7963 - val_loss: 0.5709
# Epoch 485/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7763 - loss: 0.6228 - val_accuracy: 0.7921 - val_loss: 0.5772
# Epoch 486/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7761 - loss: 0.6274 - val_accuracy: 0.7981 - val_loss: 0.5642
# Epoch 487/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7770 - loss: 0.6271 - val_accuracy: 0.7996 - val_loss: 0.5624
# Epoch 488/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7757 - loss: 0.6259 - val_accuracy: 0.7939 - val_loss: 0.5733
# Epoch 489/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7742 - loss: 0.6301 - val_accuracy: 0.7969 - val_loss: 0.5667
# Epoch 490/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7766 - loss: 0.6214 - val_accuracy: 0.7985 - val_loss: 0.5693
# Epoch 491/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7766 - loss: 0.6228 - val_accuracy: 0.7985 - val_loss: 0.5658
# Epoch 492/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7769 - loss: 0.6219 - val_accuracy: 0.7957 - val_loss: 0.5721
# Epoch 493/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7765 - loss: 0.6269 - val_accuracy: 0.7974 - val_loss: 0.5700
# Epoch 494/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7765 - loss: 0.6252 - val_accuracy: 0.7938 - val_loss: 0.5740
# Epoch 495/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7744 - loss: 0.6313 - val_accuracy: 0.8004 - val_loss: 0.5634
# Epoch 496/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7769 - loss: 0.6219 - val_accuracy: 0.7976 - val_loss: 0.5665
# Epoch 497/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7774 - loss: 0.6218 - val_accuracy: 0.7953 - val_loss: 0.5730
# Epoch 498/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7763 - loss: 0.6265 - val_accuracy: 0.7977 - val_loss: 0.5665
# Epoch 499/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7747 - loss: 0.6253 - val_accuracy: 0.7987 - val_loss: 0.5659
# Epoch 500/500
# 3233/3233 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.7760 - loss: 0.6282 - val_accuracy: 0.7955 - val_loss: 0.5699
# Test accuracy: 0.7929
# Test loss: 0.5760
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot confusion matrix
cm = confusion_matrix(y_true_classes[:len(y_pred_classes)], y_pred_classes)
plt.figure(figsize=(20, 8))

# Plot the regular confusion matrix
plt.subplot(1, 2, 1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

# Plot the normalized confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.subplot(1, 2, 2)
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Normalized Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')

plt.tight_layout()
plt.show()

# %%
# Function to predict appliance and probabilities
def predict_appliance(electrical_readings):
    # Ensure the input is a 2D array
    if electrical_readings.ndim == 1:
        electrical_readings = electrical_readings.reshape(1, -1)
    
    # Scale the input
    scaled_input = scaler.transform(electrical_readings)
    
    # Make prediction
    probabilities = model.predict(scaled_input)[0]
    predicted_class = le.inverse_transform([np.argmax(probabilities)])[0]
    
    return predicted_class, probabilities

# Example usage
example_reading = np.array([50.0, 340, 111.284, -40.89, 0.533, 224.038])
predicted_appliance, probabilities = predict_appliance(example_reading)

print(f"Predicted appliance: {predicted_appliance}")
print("Probabilities for each appliance:")
for appliance, prob in zip(le.classes_, probabilities):
    print(f"{appliance}: {prob:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted appliance: Televisions_(LCD_or_LED)
# Probabilities for each appliance:
# Coffee_machines: 0.0000
# Computers_stations_(with_monitors): 0.0000
# Fans: 0.0000
# Fridges_and_freezers: 0.0000
# Hi-Fi_systems_(with_CD_players): 0.0000
# Kettles: 0.0000
# Lamps_(compact_fluorescent): 0.0000
# Lamps_(incandescent): 0.0000
# Laptops_(via_chargers): 0.0000
# Microwave_ovens: 0.0000
# Mobile_phones_(via_chargers): 0.0000
# Monitors: 0.0000
# Printers: 0.0000
# Shavers_(via_chargers): 0.0000
# Televisions_(LCD_or_LED): 1.0000
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Plot probabilities
plt.figure(figsize=(10, 6))
sns.barplot(x=le.classes_, y=probabilities)
plt.title('Appliance Prediction Probabilities')
plt.xlabel('Appliance')
plt.ylabel('Probability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# List and find versions of Keras model files in the directory
directory_path = 'C:/Users/honey/Documents/placment work/Electronical-AI-Device-Recogniser/khanya/juyniper notbooks'  # Define the directory path

pattern = re.compile(r'appliance_recogniser#(\d+\.\d+\.\d+)\.keras')
found_files = []
for file_name in os.listdir(directory_path):
    match = pattern.match(file_name)
    if match:
        version = match.group(1)
        found_files.append((file_name, version))

if found_files:
    for file_name, version in found_files:
        print(f"Found file: {file_name} with version: {version}")
else:
    print("No Keras files found in the directory.")

def get_next_version(file_name):
    # Find version pattern like 1.1.2
    match = re.search(r'(\d+\.\d+\.\d+)', file_name)
    if match:
        version_str = match.group(1)
        version_parts = list(map(int, version_str.split('.')))
        version_parts[-1] += 1  # Increment the last number
        next_version = '.'.join(map(str, version_parts))
        return file_name.replace(version_str, next_version)
    else:
        raise ValueError("No version found in file name")

# Example for scaler
scaler_file = 'scaler1.1.3.pkl'
next_scaler_file = get_next_version(scaler_file)
joblib.dump(scaler, next_scaler_file)
print(f"Saved scaler as: {next_scaler_file}")

# Example for model
model_file = 'appliance_recogniser#1.1.2.keras'
next_model_file = get_next_version(model_file)
model.save(next_model_file)
print(f"Saved model as: {next_model_file}")
# Out:
# Found file: appliance_recogniser#1.1.1.keras with version: 1.1.1
# Found file: appliance_recogniser#1.1.3.keras with version: 1.1.3
# Saved scaler as: scaler1.1.4.pkl
# Saved model as: appliance_recogniser#1.1.3.keras

# %%
# Example for model
model_file = 'appliance_recogniser#1.1.3.keras'  # Ensure the version pattern is correct
next_model_file = get_next_version(model_file)
model.save(next_model_file)
print(f"Saved model as: {next_model_file}")

# Cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Prepare for storing metrics
all_confusion_matrices = []
all_classification_reports = []

# Cross-validation loop
for train_index, test_index in kf.split(X_resampled):
    # Split the data
    X_train, X_test = X_resampled[train_index], X_resampled[test_index]
    y_train, y_test = y_resampled[train_index], y_resampled[test_index]
    
    # One-hot encode the labels
    y_train_onehot = to_categorical(y_train, num_classes=num_classes)
    y_test_onehot = to_categorical(y_test, num_classes=num_classes)
    
    # Build and compile the model
    model = Sequential([
        Dense(128, activation='relu', input_dim=X_train.shape[1]),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(128, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, y_train_onehot, epochs=50, verbose=0)

    # Evaluate the model on the test set
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Store confusion matrix and classification report for this fold
    conf_matrix = confusion_matrix(y_test, y_pred_classes)
    all_confusion_matrices.append(conf_matrix)

    class_report = classification_report(y_test, y_pred_classes, output_dict=True)
    all_classification_reports.append(class_report)
# Out:
# Saved model as: appliance_recogniser#1.1.4.keras
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 1s 666us/step
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 1s 614us/step
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 1s 628us/step
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 1s 600us/step

# %%
# # Ensure all_confusion_matrices is a list of numpy arrays
# all_confusion_matrices = [np.array(cm) for cm in all_confusion_matrices if isinstance(cm, np.ndarray)]

# # Filter out any non-array elements
# all_confusion_matrices = [cm for cm in all_confusion_matrices if isinstance(cm, np.ndarray)]

# # Ensure the list is not empty before calculating the mean
# if all_confusion_matrices:
#     average_conf_matrix = np.mean(all_confusion_matrices, axis=0)
#     average_classification_report = {key: np.mean([report[key]['f1-score'] for report in all_classification_reports])
#                                      for key in all_classification_reports[0].keys()}

#     print('Average Confusion Matrix:')
#     print(average_conf_matrix)

#     print('Average Classification Report (F1-Scores):')
# else:
#     print('No valid confusion matrices to average.')
# for key, score in average_classification_report.items():
#     print(f'{key}: {score}')
