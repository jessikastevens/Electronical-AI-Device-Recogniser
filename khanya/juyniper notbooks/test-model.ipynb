# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
# Load the data
df = pd.read_csv('acs-f2-dataset 1.csv')

# %%
# Data Preprocessing
# Drop the 'time' column as it's not relevant for prediction
df = df.drop('time', axis=1)

# %%
# Convert categorical labels to numeric
le = LabelEncoder()
df['equipment'] = le.fit_transform(df['equipment'])

# %%
# Split features and labels
X = df.drop('equipment', axis=1)
y = df['equipment']

# %%
# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Convert labels to one-hot encoding
y_encoded = to_categorical(y)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
# Define the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_encoded.shape[1], activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.2736 - loss: 2.1466 - val_accuracy: 0.4446 - val_loss: 1.6151
# Epoch 2/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4003 - loss: 1.7085 - val_accuracy: 0.4813 - val_loss: 1.4834
# Epoch 3/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4392 - loss: 1.5938 - val_accuracy: 0.5080 - val_loss: 1.4061
# Epoch 4/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4563 - loss: 1.5423 - val_accuracy: 0.5276 - val_loss: 1.3466
# Epoch 5/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4690 - loss: 1.4905 - val_accuracy: 0.5408 - val_loss: 1.3026
# Epoch 6/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4902 - loss: 1.4413 - val_accuracy: 0.5613 - val_loss: 1.2658
# Epoch 7/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5010 - loss: 1.4101 - val_accuracy: 0.5808 - val_loss: 1.2129
# Epoch 8/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5187 - loss: 1.3652 - val_accuracy: 0.6064 - val_loss: 1.1648
# Epoch 9/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5275 - loss: 1.3448 - val_accuracy: 0.6090 - val_loss: 1.1368
# Epoch 10/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5375 - loss: 1.3153 - val_accuracy: 0.6248 - val_loss: 1.1146
# Epoch 11/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5465 - loss: 1.2921 - val_accuracy: 0.6233 - val_loss: 1.0927
# Epoch 12/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5543 - loss: 1.2709 - val_accuracy: 0.6281 - val_loss: 1.0747
# Epoch 13/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5544 - loss: 1.2692 - val_accuracy: 0.6354 - val_loss: 1.0468
# Epoch 14/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5616 - loss: 1.2486 - val_accuracy: 0.6394 - val_loss: 1.0446
# Epoch 15/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5645 - loss: 1.2389 - val_accuracy: 0.6359 - val_loss: 1.0318
# Epoch 16/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.5718 - loss: 1.2174 - val_accuracy: 0.6443 - val_loss: 1.0175
# Epoch 17/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5737 - loss: 1.2089 - val_accuracy: 0.6394 - val_loss: 1.0165
# Epoch 18/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5767 - loss: 1.2046 - val_accuracy: 0.6355 - val_loss: 1.0130
# Epoch 19/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5787 - loss: 1.1973 - val_accuracy: 0.6506 - val_loss: 0.9904
# Epoch 20/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5820 - loss: 1.1919 - val_accuracy: 0.6537 - val_loss: 0.9899
# Epoch 21/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5815 - loss: 1.1883 - val_accuracy: 0.6598 - val_loss: 0.9770
# Epoch 22/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5835 - loss: 1.1863 - val_accuracy: 0.6621 - val_loss: 0.9763
# Epoch 23/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5896 - loss: 1.1684 - val_accuracy: 0.6679 - val_loss: 0.9668
# Epoch 24/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5940 - loss: 1.1620 - val_accuracy: 0.6677 - val_loss: 0.9596
# Epoch 25/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.5892 - loss: 1.1707 - val_accuracy: 0.6657 - val_loss: 0.9534
# Epoch 26/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.5923 - loss: 1.1652 - val_accuracy: 0.6658 - val_loss: 0.9646
# Epoch 27/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.5961 - loss: 1.1463 - val_accuracy: 0.6703 - val_loss: 0.9400
# Epoch 28/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5981 - loss: 1.1439 - val_accuracy: 0.6683 - val_loss: 0.9398
# Epoch 29/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5970 - loss: 1.1467 - val_accuracy: 0.6632 - val_loss: 0.9457
# Epoch 30/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5971 - loss: 1.1477 - val_accuracy: 0.6736 - val_loss: 0.9360
# Epoch 31/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6023 - loss: 1.1318 - val_accuracy: 0.6704 - val_loss: 0.9263
# Epoch 32/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6007 - loss: 1.1345 - val_accuracy: 0.6721 - val_loss: 0.9307
# Epoch 33/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.5986 - loss: 1.1339 - val_accuracy: 0.6658 - val_loss: 0.9258
# Epoch 34/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6077 - loss: 1.1232 - val_accuracy: 0.6766 - val_loss: 0.9234
# Epoch 35/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.6083 - loss: 1.1182 - val_accuracy: 0.6822 - val_loss: 0.9162
# Epoch 36/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6033 - loss: 1.1189 - val_accuracy: 0.6850 - val_loss: 0.9054
# Epoch 37/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6066 - loss: 1.1214 - val_accuracy: 0.6821 - val_loss: 0.9040
# Epoch 38/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6092 - loss: 1.1162 - val_accuracy: 0.6740 - val_loss: 0.9143
# Epoch 39/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6091 - loss: 1.1155 - val_accuracy: 0.6842 - val_loss: 0.9120
# Epoch 40/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6115 - loss: 1.1056 - val_accuracy: 0.6854 - val_loss: 0.9086
# Epoch 41/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6099 - loss: 1.1130 - val_accuracy: 0.6800 - val_loss: 0.9034
# Epoch 42/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6121 - loss: 1.1052 - val_accuracy: 0.6796 - val_loss: 0.9080
# Epoch 43/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6121 - loss: 1.1041 - val_accuracy: 0.6873 - val_loss: 0.8995
# Epoch 44/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6114 - loss: 1.1054 - val_accuracy: 0.6792 - val_loss: 0.9113
# Epoch 45/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6122 - loss: 1.1040 - val_accuracy: 0.6936 - val_loss: 0.8874
# Epoch 46/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6136 - loss: 1.0954 - val_accuracy: 0.6782 - val_loss: 0.9042
# Epoch 47/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6161 - loss: 1.0934 - val_accuracy: 0.6810 - val_loss: 0.8917
# Epoch 48/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6162 - loss: 1.0954 - val_accuracy: 0.6883 - val_loss: 0.8927
# Epoch 49/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6154 - loss: 1.0975 - val_accuracy: 0.6869 - val_loss: 0.8932
# Epoch 50/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6148 - loss: 1.0910 - val_accuracy: 0.6867 - val_loss: 0.8893
# Epoch 51/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6168 - loss: 1.0913 - val_accuracy: 0.6831 - val_loss: 0.8901
# Epoch 52/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6186 - loss: 1.0851 - val_accuracy: 0.6938 - val_loss: 0.8740
# Epoch 53/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6195 - loss: 1.0827 - val_accuracy: 0.6969 - val_loss: 0.8845
# Epoch 54/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.6176 - loss: 1.0934 - val_accuracy: 0.6848 - val_loss: 0.8877
# Epoch 55/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6197 - loss: 1.0846 - val_accuracy: 0.6846 - val_loss: 0.8837
# Epoch 56/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6229 - loss: 1.0760 - val_accuracy: 0.6937 - val_loss: 0.8755
# Epoch 57/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6188 - loss: 1.0784 - val_accuracy: 0.6909 - val_loss: 0.8665
# Epoch 58/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6223 - loss: 1.0752 - val_accuracy: 0.6887 - val_loss: 0.8907
# Epoch 59/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6219 - loss: 1.0801 - val_accuracy: 0.6953 - val_loss: 0.8706
# Epoch 60/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6226 - loss: 1.0760 - val_accuracy: 0.6934 - val_loss: 0.8772
# Epoch 61/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6225 - loss: 1.0672 - val_accuracy: 0.6882 - val_loss: 0.8779
# Epoch 62/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6270 - loss: 1.0651 - val_accuracy: 0.7036 - val_loss: 0.8669
# Epoch 63/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6246 - loss: 1.0743 - val_accuracy: 0.6918 - val_loss: 0.8708
# Epoch 64/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6258 - loss: 1.0744 - val_accuracy: 0.6949 - val_loss: 0.8690
# Epoch 65/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6251 - loss: 1.0650 - val_accuracy: 0.7081 - val_loss: 0.8616
# Epoch 66/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6236 - loss: 1.0658 - val_accuracy: 0.6991 - val_loss: 0.8636
# Epoch 67/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6279 - loss: 1.0584 - val_accuracy: 0.6997 - val_loss: 0.8613
# Epoch 68/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6291 - loss: 1.0614 - val_accuracy: 0.6973 - val_loss: 0.8571
# Epoch 69/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6261 - loss: 1.0682 - val_accuracy: 0.7016 - val_loss: 0.8612
# Epoch 70/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6267 - loss: 1.0638 - val_accuracy: 0.6967 - val_loss: 0.8556
# Epoch 71/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6276 - loss: 1.0590 - val_accuracy: 0.6987 - val_loss: 0.8531
# Epoch 72/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6261 - loss: 1.0656 - val_accuracy: 0.7014 - val_loss: 0.8551
# Epoch 73/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6305 - loss: 1.0557 - val_accuracy: 0.6970 - val_loss: 0.8582
# Epoch 74/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6318 - loss: 1.0545 - val_accuracy: 0.6991 - val_loss: 0.8592
# Epoch 75/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6279 - loss: 1.0615 - val_accuracy: 0.7091 - val_loss: 0.8471
# Epoch 76/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6301 - loss: 1.0552 - val_accuracy: 0.7017 - val_loss: 0.8527
# Epoch 77/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6319 - loss: 1.0513 - val_accuracy: 0.7046 - val_loss: 0.8503
# Epoch 78/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6320 - loss: 1.0516 - val_accuracy: 0.7049 - val_loss: 0.8477
# Epoch 79/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6366 - loss: 1.0452 - val_accuracy: 0.7087 - val_loss: 0.8567
# Epoch 80/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6286 - loss: 1.0619 - val_accuracy: 0.7016 - val_loss: 0.8521
# Epoch 81/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6318 - loss: 1.0532 - val_accuracy: 0.7034 - val_loss: 0.8480
# Epoch 82/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6299 - loss: 1.0519 - val_accuracy: 0.6999 - val_loss: 0.8532
# Epoch 83/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6321 - loss: 1.0434 - val_accuracy: 0.7045 - val_loss: 0.8441
# Epoch 84/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6334 - loss: 1.0432 - val_accuracy: 0.7049 - val_loss: 0.8456
# Epoch 85/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.6336 - loss: 1.0491 - val_accuracy: 0.6994 - val_loss: 0.8509
# Epoch 86/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6322 - loss: 1.0412 - val_accuracy: 0.7075 - val_loss: 0.8444
# Epoch 87/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6324 - loss: 1.0480 - val_accuracy: 0.7075 - val_loss: 0.8508
# Epoch 88/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6314 - loss: 1.0454 - val_accuracy: 0.7080 - val_loss: 0.8433
# Epoch 89/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6340 - loss: 1.0436 - val_accuracy: 0.7116 - val_loss: 0.8466
# Epoch 90/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6344 - loss: 1.0490 - val_accuracy: 0.7019 - val_loss: 0.8549
# Epoch 91/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6351 - loss: 1.0437 - val_accuracy: 0.7029 - val_loss: 0.8501
# Epoch 92/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6295 - loss: 1.0566 - val_accuracy: 0.7057 - val_loss: 0.8508
# Epoch 93/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6349 - loss: 1.0482 - val_accuracy: 0.7030 - val_loss: 0.8524
# Epoch 94/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6345 - loss: 1.0420 - val_accuracy: 0.6967 - val_loss: 0.8504
# Epoch 95/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6352 - loss: 1.0399 - val_accuracy: 0.7101 - val_loss: 0.8517
# Epoch 96/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.6322 - loss: 1.0518 - val_accuracy: 0.7020 - val_loss: 0.8422
# Epoch 97/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6332 - loss: 1.0492 - val_accuracy: 0.7102 - val_loss: 0.8417
# Epoch 98/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6356 - loss: 1.0443 - val_accuracy: 0.7108 - val_loss: 0.8451
# Epoch 99/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6354 - loss: 1.0451 - val_accuracy: 0.7074 - val_loss: 0.8368
# Epoch 100/100
# 3223/3223 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.6340 - loss: 1.0441 - val_accuracy: 0.7058 - val_loss: 0.8505

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Test accuracy: 0.7029
# Test loss: 0.8585

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()

# %%
# Function to predict appliance and probabilities
def predict_appliance(electrical_readings):
    # Ensure the input is a 2D array
    if electrical_readings.ndim == 1:
        electrical_readings = electrical_readings.reshape(1, -1)
    
    # Scale the input
    scaled_input = scaler.transform(electrical_readings)
    
    # Make prediction
    probabilities = model.predict(scaled_input)[0]
    predicted_class = le.inverse_transform([np.argmax(probabilities)])[0]
    
    return predicted_class, probabilities

# %%
# Example usage
example_reading = np.array([50.0, 340, 111.284, -40.89, 0.533, 224.038])
predicted_appliance, probabilities = predict_appliance(example_reading)

print(f"Predicted appliance: {predicted_appliance}")
print("Probabilities for each appliance:")
for appliance, prob in zip(le.classes_, probabilities):
    print(f"{appliance}: {prob:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted appliance: Televisions_(LCD_or_LED)
# Probabilities for each appliance:
# Coffee_machines: 0.0000
# Computers_stations_(with_monitors): 0.0076
# Fans: 0.0000
# Fridges_and_freezers: 0.0000
# Hi-Fi_systems_(with_CD_players): 0.0000
# Kettles: 0.0000
# Lamps_(compact_fluorescent): 0.0000
# Lamps_(incandescent): 0.0000
# Laptops_(via_chargers): 0.0000
# Microwave_ovens: 0.0000
# Mobile_phones_(via_chargers): 0.0000
# Monitors: 0.0000
# Printers: 0.0000
# Shavers_(via_chargers): 0.0000
# Televisions_(LCD_or_LED): 0.9923
# c:\Users\honey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Plot probabilities
plt.figure(figsize=(10, 6))
sns.barplot(x=le.classes_, y=probabilities)
plt.title('Appliance Prediction Probabilities')
plt.xlabel('Appliance')
plt.ylabel('Probability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
